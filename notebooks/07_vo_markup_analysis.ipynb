# %%
import pandas as pd
import matplotlib.pyplot as plt
caminho_do_arquivo = 'C:\\Users\\vinciaott\\OneDrive\\Área de Trabalho\\Tabela_com_selecao_features.csv'

df = pd.read_csv(caminho_do_arquivo)

print(df.columns)
# Out:
# Index(['Area', 'Year',
#        'Cost of a healthy diet (PPP dollar per person per day)',
#        'Coefficient of human inequality', 'Human Development Index (value)',
#        'Inequality in eduation', 'Inequality in income',
#        'Inequality in life expectancy',
#        '2.a.1 Agriculture share of Government Expenditure',
#        '2.a.1 Agriculture value added share of GDP',
#        '6.4.1 Water Use Efficiency (Agriculture (ISIC4 A01 A0210 A0322))',
#        '6.4.1 Water Use Efficiency (Industries)',
#        'Gross domestic product per capita, PPP, (constant 2017 international $)',
#        'Per capita food supply variability (kcal/cap/day)',
#        'Value of food imports in total merchandise exports (percent) (3-year average)',
#        'Prevalence of undernourishment (percent) (3-year average)',
#        'Percentage of the population unable to afford a healthy diet (percent)'],
#       dtype='object')

# %%
colunas_especificas = ['Area', 'Year', 'Cost of a healthy diet (PPP dollar per person per day)']
df_selecionado = df[colunas_especificas]

# %%
df_selecionado.head()
# Out:
#       Area  Year  Cost of a healthy diet (PPP dollar per person per day)
# 0  Armenia  2017                                              3.096
# 1  Armenia  2018                                              3.166
# 2  Armenia  2019                                              3.237
# 3  Armenia  2020                                              3.247
# 4  Armenia  2021                                              3.527

# %%
df_brazil = df_selecionado[df_selecionado['Area'] == 'Brazil']
df_brazil.head()
# Out:
#       Area  Year  Cost of a healthy diet (PPP dollar per person per day)
# 95  Brazil  2017                                              2.809
# 96  Brazil  2018                                              2.800
# 97  Brazil  2019                                              2.882
# 98  Brazil  2020                                              3.084
# 99  Brazil  2021                                              3.350

# %%
# Convertendo a coluna 'Year' para inteiros e ordenando
df_brazil['Year'] = df_brazil['Year'].astype(int)
df_brazil = df_brazil.sort_values('Year')

# Plotando o gráfico
plt.figure(figsize=(10, 6))
plt.plot(df_brazil['Year'], df_brazil['Cost of a healthy diet (PPP dollar per person per day)'], marker='o', linestyle='-')

# Adicionando títulos e rótulos
plt.title('Custo de uma Dieta Saudável no Brazil ao Longo dos Anos', fontsize=14)
plt.xlabel('Ano', fontsize=12)
plt.ylabel('Custo de uma Dieta Saudável (PPP dólar por pessoa por dia)', fontsize=12)
plt.grid(True)

# Ajustando os ticks do eixo x para mostrar todos os anos
plt.xticks(df_brazil['Year'], rotation=45)

# Exibindo o gráfico
plt.show()
# Out:
# C:\Users\vinciaott\AppData\Local\Temp\ipykernel_1252\2715811480.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brazil['Year'] = df_brazil['Year'].astype(int)

# %%
# Filtrando para o ano de 2021
df_2021 = df_selecionado[df_selecionado['Year'] == 2021]

# Encontrando os 10 maiores custos em 2021
df_maiores_custos_2021 = df_2021.nlargest(80, 'Cost of a healthy diet (PPP dollar per person per day)')

# Exibindo os 10 maiores custos em 2021
df_maiores_custos_2021
# Out:
#              Area  Year  \
# 429       Jamaica  2021
# 339       Grenada  2021
# 815      Suriname  2021
# 559      Mongolia  2021
# 434         Japan  2021
# ..            ...   ...
# 980        Zambia  2021
# 930  Burkina Faso  2021
# 820    Tajikistan  2021
# 364      Honduras  2021
# 570    Mozambique  2021
#
#      Cost of a healthy diet (PPP dollar per person per day)
# 429                                              7.033
# 339                                              6.097
# 815                                              6.090
# 559                                              5.676
# 434                                              5.638
# ..                                                 ...
# 980                                              3.616
# 930                                              3.611
# 820                                              3.610
# 364                                              3.595
# ...

# %%
# Lista de países da América Latina
paises_latam = [
    'Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Costa Rica', 'Cuba', 'Dominican Republic',
    'Ecuador', 'El Salvador', 'Guatemala', 'Honduras', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 
    'Peru', 'Uruguay', 'Venezuela'
]
# Selecionando as colunas específicas
colunas_especificas = ['Area', 'Year', 'Cost of a healthy diet (PPP dollar per person per day)']
df_selecionado = df[colunas_especificas]

# Filtrando para a América Latina e o ano de 2021
df_latam_2021 = df_selecionado[(df_selecionado['Year'] == 2021) & (df_selecionado['Area'].isin(paises_latam))]

# Encontrando os 10 maiores custos em 2021 na América Latina
df_maiores_custos_latam_2021 = df_latam_2021.nlargest(13, 'Cost of a healthy diet (PPP dollar per person per day)')

# %%
(df_maiores_custos_latam_2021)
# Out:
#                    Area  Year  \
# 655              Panama  2021
# 234  Dominican Republic  2021
# 199          Costa Rica  2021
# 670            Paraguay  2021
# 364            Honduras  2021
# 935             Uruguay  2021
# 625           Nicaragua  2021
# 174               Chile  2021
# 99               Brazil  2021
# 675                Peru  2021
# 179            Colombia  2021
# 554              Mexico  2021
# 244             Ecuador  2021
#
#      Cost of a healthy diet (PPP dollar per person per day)
# 655                                              4.687
# 234                                              4.128
# 199                                              3.925
# 670                                              3.867
# 364                                              3.595
# 935                                              3.543
# 625                                              3.540
# 174                                              3.387
# ...

# %%
#Lista de países da América Latina
paises_latam = [
    'Argentina', 'Bolivia', 'Brazil', 'Chile', 'Colombia', 'Costa Rica', 'Cuba', 'Dominican Republic',
    'Ecuador', 'El Salvador', 'Guatemala', 'Honduras', 'Mexico', 'Nicaragua', 'Panama', 'Paraguay', 
    'Peru', 'Uruguay', 'Venezuela'
]


# Ordenando os dados para visualização
df_maiores_custos_latam_2021 = df_maiores_custos_latam_2021.sort_values('Cost of a healthy diet (PPP dollar per person per day)', ascending=False)

# Criando uma lista de cores, destacando o Brasil
colors = ['yellow' if area == 'Brazil' else 'skyblue' for area in df_maiores_custos_latam_2021['Area']]

# Plotando o gráfico de barras
plt.figure(figsize=(12, 8))
plt.barh(df_maiores_custos_latam_2021['Area'], df_maiores_custos_latam_2021['Cost of a healthy diet (PPP dollar per person per day)'], color=colors)
plt.xlabel('Custo de uma Dieta Saudável (PPP dólar por pessoa por dia)', fontsize=12)
plt.ylabel('Área', fontsize=12)
plt.title('Os 13 Custos Mais Elevados de uma Dieta Saudável na América Latina em 2021', fontsize=14)
plt.gca().invert_yaxis()  # Inverter o eixo y para que o maior custo esteja no topo

# Adicionando os valores nas barras
for index, value in enumerate(df_maiores_custos_latam_2021['Cost of a healthy diet (PPP dollar per person per day)']):
    plt.text(value, index, f'{value:.2f}', va='center', ha='left', fontsize=10, color='black')

# Exibindo o gráfico
plt.show()
