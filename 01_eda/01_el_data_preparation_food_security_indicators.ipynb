# %% [markdown]
# # 1 Introduction

# %% [markdown]
# > Notebook para preparação dos dados de suite of food security indicators da FAO
# >
# > Dados abertos de https://www.fao.org/faostat/en/#data/FS

# %% [markdown]
# ## 1.1 Business needs

# %% [markdown]
# > Carga e preparação dos dados abertos

# %% [markdown]
# ## 1.2 Dependencies

# %% [markdown]
# > What dependencies does the reader need to download in order to run the whole notebook? Write the pip or conda command to allow easy access to those. Be sure to include the specific versions if needed be.

# %%
# !pip install pandas
# !pip install -U NumPy==1.23.2
# !pip install ydata-profiling
# !pip install --upgrade pip
# !pip install --upgrade Pillow
# !pip install pyarrow
# !pip install fastparquet

# %% [markdown]
# ## 1.3 Imports

# %% [markdown]
# > Import all libraries needed. Include the latest versions used to allow reproducibility.

# %%
import pandas as pd
from ydata_profiling import ProfileReport      # Para análise exploratória dos dados
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1.4 Global variables

# %% [markdown]
# > Declare all variables that will retain a constant value throught the notebook. For exemple, the path to the input data should be a global variable.

# %% [markdown]
# # 2 Exploratory data analysis

# %% [markdown]
# > Write a brief summary about which analysis and wrangling was performed.

# %% [markdown]
# ## 2.1 Data reading

# %% [markdown]
# > Give a brief introduction to the data used and their sources.

# %%
df = pd.read_csv("../data/1. Suite of Food Security Indicators/Food_Security_Data_E_All_Data_(Normalized).csv", encoding='ISO-8859–1')

# %% [markdown]
# ### Análise inicial

# %%
df.columns
# Out:
# Index(['Area Code', 'Area Code (M49)', 'Area', 'Item Code', 'Item',
#        'Element Code', 'Element', 'Year Code', 'Year', 'Unit', 'Value', 'Flag',
#        'Note'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233305 entries, 0 to 233304
# Data columns (total 13 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Area Code        233305 non-null  int64
#  1   Area Code (M49)  233305 non-null  object
#  2   Area             233305 non-null  object
#  3   Item Code        233305 non-null  object
#  4   Item             233305 non-null  object
#  5   Element Code     233305 non-null  int64
#  6   Element          233305 non-null  object
#  7   Year Code        233305 non-null  int64
#  8   Year             233305 non-null  object
#  9   Unit             229231 non-null  object
#  10  Value            200258 non-null  object
#  11  Flag             233305 non-null  object
#  12  Note             31184 non-null   object
# dtypes: int64(3), object(10)
# memory usage: 23.1+ MB

# %%
df.describe()
# Out:
#            Area Code   Element Code     Year Code
# count  233305.000000  233305.000000  2.333050e+05
# mean     1460.402885   19457.594304  9.312173e+06
# std      2363.708778   23607.567432  1.004072e+07
# min         1.000000    6121.000000  2.000000e+03
# 25%        91.000000    6121.000000  2.012000e+03
# 50%       171.000000    6128.000000  2.021000e+03
# 75%       420.000000    6173.000000  2.015202e+07
# max      9011.000000   61322.000000  2.020202e+07

# %%
df.head().T
# Out:
#                                                                  0  \
# Area Code                                                        2
# Area Code (M49)                                               '004
# Area                                                   Afghanistan
# Item Code                                                    21010
# Item             Average dietary energy supply adequacy (percen...
# Element Code                                                  6121
# Element                                                      Value
# Year Code                                                 20002002
# Year                                                     2000-2002
# Unit                                                             %
# Value                                                           88
# Flag                                                             E
# Note                                                           NaN
#
#                                                                  1  \
# Area Code                                                        2
# Area Code (M49)                                               '004
# Area                                                   Afghanistan
# Item Code                                                    21010
# Item             Average dietary energy supply adequacy (percen...
# Element Code                                                  6121
# Element                                                      Value
# Year Code                                                 20012003
# Year                                                     2001-2003
# Unit                                                             %
# Value                                                           89
# Flag                                                             E
# Note                                                           NaN
#
#                                                                  2  \
# Area Code                                                        2
# Area Code (M49)                                               '004
# Area                                                   Afghanistan
# Item Code                                                    21010
# Item             Average dietary energy supply adequacy (percen...
# Element Code                                                  6121
# Element                                                      Value
# Year Code                                                 20022004
# Year                                                     2002-2004
# Unit                                                             %
# Value                                                           92
# Flag                                                             E
# Note                                                           NaN
#
#                                                                  3  \
# Area Code                                                        2
# Area Code (M49)                                               '004
# Area                                                   Afghanistan
# Item Code                                                    21010
# Item             Average dietary energy supply adequacy (percen...
# Element Code                                                  6121
# Element                                                      Value
# Year Code                                                 20032005
# Year                                                     2003-2005
# Unit                                                             %
# Value                                                           93
# Flag                                                             E
# Note                                                           NaN
#
#                                                                  4
# Area Code                                                        2
# Area Code (M49)                                               '004
# Area                                                   Afghanistan
# Item Code                                                    21010
# Item             Average dietary energy supply adequacy (percen...
# Element Code                                                  6121
# Element                                                      Value
# Year Code                                                 20042006
# Year                                                     2004-2006
# Unit                                                             %
# Value                                                           94
# Flag                                                             E
# Note                                                           NaN

# %% [markdown]
# ## 2.2 Data wrangling

# %% [markdown]
# > Guide the reader about which data wranglings were needed and why

# %% [markdown]
# ### Análise Exploratória Inicial

# %%
profile = ProfileReport(df)
profile.to_file("../output/report.html", silent=True)

# profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# #### Análise da coluna Element

# %%
df.groupby('Element')['Element'].agg('count')
# Out:
# Element
# Confidence interval: Lower bound     28206
# Confidence interval: Upper bound     28206
# Value                               176893
# Name: Element, dtype: int64

# %%
df[df['Element'] != 'Value'].head()
# Out:
#      Area Code Area Code (M49)         Area Item Code  \
# 147          2            '004  Afghanistan    210401
# 148          2            '004  Afghanistan    210401
# 149          2            '004  Afghanistan    210401
# 150          2            '004  Afghanistan    210401
# 151          2            '004  Afghanistan    210401
#
#                                                   Item  Element Code  \
# 147  Prevalence of severe food insecurity in the to...         61211
# 148  Prevalence of severe food insecurity in the to...         61211
# 149  Prevalence of severe food insecurity in the to...         61211
# 150  Prevalence of severe food insecurity in the to...         61211
# 151  Prevalence of severe food insecurity in the to...         61211
#
#                               Element  Year Code       Year Unit Value Flag  \
# 147  Confidence interval: Lower bound   20142016  2014-2016    %    11    A
# 148  Confidence interval: Lower bound   20152017  2015-2017    %  11.8    A
# 149  Confidence interval: Lower bound   20162018  2016-2018    %  14.5    A
# 150  Confidence interval: Lower bound   20172019  2017-2019    %  15.2    A
# 151  Confidence interval: Lower bound   20182020  2018-2020    %  17.5    A
#
#                   Note
# 147           FAO data
# 148           FAO data
# 149           FAO data
# 150  Official estimate
# 151  Official estimate

# %% [markdown]
# #### Análise de Item Code

# %%
df.groupby(['Item Code'])['Item Code'].agg('count')
# Out:
# Item Code
# 210010    1035
# 210011    5227
# 210040    1035
# 210041    5229
# 210070    1215
#           ...
# 21057     5497
# 21058     4416
# 21059     4669
# 21061     4196
# 22013     5090
# Name: Item Code, Length: 68, dtype: int64

# %%
# Exportação para o XLS para análise dos itens que ficarão
df.groupby(['Item Code', 'Item'])[['Item Code', 'Item']].agg('count').to_excel('../output/food_security_industry_features.xlsx') # Exportar para arquivo excel

# %%
# Lista das features que serão desconsideradas
df_item_code_exclude = ['210011', '210041', '210070F', '210070M', '210071', '210071F', '210071M', 
                   '210080F', '210080M', '210081', '210081F', '210081M', '210090F', '210090M', 
                   '210091', '210091F', '210091M', '21025', '210250', '21026', '210260', '21034', 
                   '210400F', '210400M', '210400R', '210400TSUB', '210400U', '210401', '210401F', 
                   '210401M', '21041', '210410', '21043', '210430', '21044', '21049', '210490', '21057']

# %% [markdown]
# #### Análise da coluna Year e Year Code

# %%
df.groupby('Year')['Year'].agg('count')
# Out:
# Year
# 2000          4663
# 2000-2002     2244
# 2001          4600
# 2001-2003     2244
# 2002          4800
# 2002-2004     2245
# 2003          4812
# 2003-2005     2246
# 2004          4829
# 2004-2006     2250
# 2005          4857
# 2005-2007     2260
# 2006          4903
# 2006-2008     2260
# 2007          4858
# 2007-2009     2260
# 2008          4842
# 2008-2010     2267
# 2009          4840
# 2009-2011     2267
# 2010          4885
# 2010-2012     2294
# 2011          4857
# 2011-2013     2299
# 2012          4923
# 2012-2014     2291
# 2013          4844
# 2013-2015     2289
# 2014          7327
# 2014-2016    11255
# 2015          7283
# 2015-2017    11255
# 2016          7302
# 2016-2018    11258
# 2017          6833
# 2017-2019    11273
# 2018          6859
# 2018-2020    11271
# 2019          6842
# 2019-2021    10148
# 2020          6297
# 2020-2022     9682
# 2021          4879
# 2022          4312
# Name: Year, dtype: int64

# %%
df[(df['Year Code'] > 20000000)].groupby('Year')['Year'].agg('count')
# Out:
# Year
# 2000-2002     2244
# 2001-2003     2244
# 2002-2004     2245
# 2003-2005     2246
# 2004-2006     2250
# 2005-2007     2260
# 2006-2008     2260
# 2007-2009     2260
# 2008-2010     2267
# 2009-2011     2267
# 2010-2012     2294
# 2011-2013     2299
# 2012-2014     2291
# 2013-2015     2289
# 2014-2016    11255
# 2015-2017    11255
# 2016-2018    11258
# 2017-2019    11273
# 2018-2020    11271
# 2019-2021    10148
# 2020-2022     9682
# Name: Year, dtype: int64

# %% [markdown]
# #### Análise da Coluna Area Code

# %%
df_area_code_exclude = [420, 429]

# %% [markdown]
# #### Conclusões

# %% [markdown]
# - Valores faltantes:
#
# | Campo  | Qtde  |   %  |
# |-------|--------|-------|
# | Unit  | 4074   | 1,7%  |
# | Value | 33047  | 14,2% |
# | Note  | 202121 | 86,6% |
#
# - Flag igual a Q representa linhas com valores vazios
#
# > Eliminar coluna Note
# > Eliminar linhas com campos nulos
# > Sobrarão 84% da base (196184 linhas)
#
# - Area Code na casa dos 5000 são agregações regionais (por continente ou sub-continente)
# - Area Code na casa dos 9000 são agregações econômicas (países de melhor ou pior renda)
# - 2 agregações regionais são lixo na base (420 - Sub-Saharan Africa e 429 - Northern Africa (excluding Sudan))
# > Deixar apenas as Area Codes < 5000 e eliminar as exceções 420 e 429
#
# - Linhas possuem Valores e intervalos de confiança
# > Eliminar os intervalos de confiança e a coluna 'Element'
#
# - Campos Item e Item Code são equivalentes
# > Eliminar campo Item Code
#
# - Campos Year e Year Code, em algumas pesquisas trazem um range de anos. Elas representam a média dos 3 anos da pesquisa
# > Vamos considerar que o valor representa a informação do ano final
#
# - Dados de 2000 a 2022
# > Manteremos dados nos períodos disponíveis nas outras bases estudadas: 2017-2021

# %% [markdown]
# ### Limpeza e tratamento dos dados

# %%
# Converter o campo Year para o ano inicial e final da pesquisa
df['Year'] = df['Year'].str[-4:].astype('int')

df.head()
# Out:
#    Area Code Area Code (M49)         Area Item Code  \
# 0          2            '004  Afghanistan     21010
# 1          2            '004  Afghanistan     21010
# 2          2            '004  Afghanistan     21010
# 3          2            '004  Afghanistan     21010
# 4          2            '004  Afghanistan     21010
#
#                                                 Item  Element Code Element  \
# 0  Average dietary energy supply adequacy (percen...          6121   Value
# 1  Average dietary energy supply adequacy (percen...          6121   Value
# 2  Average dietary energy supply adequacy (percen...          6121   Value
# 3  Average dietary energy supply adequacy (percen...          6121   Value
# 4  Average dietary energy supply adequacy (percen...          6121   Value
#
#    Year Code  Year Unit Value Flag Note
# 0   20002002  2002    %    88    E  NaN
# 1   20012003  2003    %    89    E  NaN
# 2   20022004  2004    %    92    E  NaN
# 3   20032005  2005    %    93    E  NaN
# 4   20042006  2006    %    94    E  NaN

# %%
# Eliminando features não relevantes ao estudo
df_drop1 = df.drop(df[df['Item Code'].isin(df_item_code_exclude)].index)

# Eliminando os anos anteriores a 2017
df_drop2 = df_drop1.drop(df_drop1[(df_drop1['Year'].astype('int') < 2017)].index)

# Eliminando os anos anteriores maiores que 2021 and não são triênios
df_drop3 = df_drop2.drop(df_drop2[(df_drop2['Year'].astype('int') > 2022)].index)

# Eliminando agregações regionais ou econômicas
df_drop4 = df_drop3.drop(df_drop3[(df_drop3['Area Code'] >= 5000) | (df_drop3['Area Code'].isin(df_area_code_exclude))].index)

# Eliminando valores representando intervalos de confiança
df_drop5 = df_drop4.drop(df_drop4[(df_drop4['Element'] != 'Value')].index)

df_drop5
# Out:
#         Area Code Area Code (M49)         Area Item Code  \
# 15              2            '004  Afghanistan     21010
# 16              2            '004  Afghanistan     21010
# 17              2            '004  Afghanistan     21010
# 18              2            '004  Afghanistan     21010
# 19              2            '004  Afghanistan     21010
# ...           ...             ...          ...       ...
# 173780        181            '716     Zimbabwe     21059
# 173796        181            '716     Zimbabwe     21061
# 173797        181            '716     Zimbabwe     21061
# 173798        181            '716     Zimbabwe     21061
# 173799        181            '716     Zimbabwe     21061
#
#                                                      Item  Element Code  \
# 15      Average dietary energy supply adequacy (percen...          6121
# 16      Average dietary energy supply adequacy (percen...          6121
# 17      Average dietary energy supply adequacy (percen...          6121
# 18      Average dietary energy supply adequacy (percen...          6121
# 19      Average dietary energy supply adequacy (percen...          6121
# ...                                                   ...           ...
# 173780  Incidence of caloric losses at retail distribu...          6121
# 173796    Average fat supply (g/cap/day) (3-year average)          6123
# 173797    Average fat supply (g/cap/day) (3-year average)          6123
# 173798    Average fat supply (g/cap/day) (3-year average)          6123
# 173799    Average fat supply (g/cap/day) (3-year average)          6123
#
#        Element  Year Code  Year     Unit Value Flag Note
# 15       Value   20152017  2017        %   108    E  NaN
# 16       Value   20162018  2018        %   108    E  NaN
# 17       Value   20172019  2019        %   107    E  NaN
# 18       Value   20182020  2020        %   106    E  NaN
# 19       Value   20192021  2021        %   106    E  NaN
# ...        ...        ...   ...      ...   ...  ...  ...
# 173780   Value       2022  2022        %  2.13    E  NaN
# 173796   Value   20152017  2017  g/cap/d  68.6    E  NaN
# 173797   Value   20162018  2018  g/cap/d  66.9    E  NaN
# 173798   Value   20172019  2019  g/cap/d  63.6    E  NaN
# 173799   Value   20182020  2020  g/cap/d  63.3    E  NaN
#
# [15495 rows x 13 columns]

# %%
# Eliminando colunas irrelevantes
df2 = df_drop5.drop(['Area Code', 'Area Code (M49)', 'Note', 'Element Code', 
                     'Element', 'Year Code', 'Flag'], axis=1).dropna().copy(deep=True)

df2.count()
# Out:
# Area         14515
# Item Code    14515
# Item         14515
# Year         14515
# Unit         14515
# Value        14515
# dtype: int64

# %%
df2[['Area', 'Item Code', 'Item', 'Unit']] = df2[['Area', 'Item Code', 'Item', 'Unit']].astype('string')
df2[['Year']] = df2[['Year']].astype('int')
df2[['Value']] = df2[['Value']].astype('float')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14515 entries, 15 to 173799
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Area       14515 non-null  string
#  1   Item Code  14515 non-null  string
#  2   Item       14515 non-null  string
#  3   Year       14515 non-null  int64
#  4   Unit       14515 non-null  string
#  5   Value      14515 non-null  float64
# dtypes: float64(1), int64(1), string(4)
# memory usage: 793.8 KB

# %%
df2
# Out:
#                Area Item Code  \
# 15      Afghanistan     21010
# 16      Afghanistan     21010
# 17      Afghanistan     21010
# 18      Afghanistan     21010
# 19      Afghanistan     21010
# ...             ...       ...
# 173780     Zimbabwe     21059
# 173796     Zimbabwe     21061
# 173797     Zimbabwe     21061
# 173798     Zimbabwe     21061
# 173799     Zimbabwe     21061
#
#                                                      Item  Year     Unit  \
# 15      Average dietary energy supply adequacy (percen...  2017        %
# 16      Average dietary energy supply adequacy (percen...  2018        %
# 17      Average dietary energy supply adequacy (percen...  2019        %
# 18      Average dietary energy supply adequacy (percen...  2020        %
# 19      Average dietary energy supply adequacy (percen...  2021        %
# ...                                                   ...   ...      ...
# 173780  Incidence of caloric losses at retail distribu...  2022        %
# 173796    Average fat supply (g/cap/day) (3-year average)  2017  g/cap/d
# 173797    Average fat supply (g/cap/day) (3-year average)  2018  g/cap/d
# 173798    Average fat supply (g/cap/day) (3-year average)  2019  g/cap/d
# 173799    Average fat supply (g/cap/day) (3-year average)  2020  g/cap/d
#
#          Value
# 15      108.00
# 16      108.00
# 17      107.00
# 18      106.00
# 19      106.00
# ...        ...
# 173780    2.13
# 173796   68.60
# 173797   66.90
# 173798   63.60
# 173799   63.30
#
# [14515 rows x 6 columns]

# %% [markdown]
# ### Análise Exploratória após limpeza dos dados

# %%
# Análise exploratória após limpeza dos dados
profile = ProfileReport(df2)
profile.to_file("../output/report2.html", silent=True)

# profile.to_notebook_iframe()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# #### Preparar o tabela Pivot para merge com as outras bases
#
# Tabela com Pais(Area), Ano e as variáveis de análise (título é o Item)

# %%
df_pivot = df2.pivot(index=['Area', 'Year'],
                    columns='Item',
                    values='Value').reset_index()

# %%
df_pivot
# Out:
# Item         Area  Year  \
# 0     Afghanistan  2017
# 1     Afghanistan  2018
# 2     Afghanistan  2019
# 3     Afghanistan  2020
# 4     Afghanistan  2021
# ...           ...   ...
# 1219     Zimbabwe  2018
# 1220     Zimbabwe  2019
# 1221     Zimbabwe  2020
# 1222     Zimbabwe  2021
# 1223     Zimbabwe  2022
#
# Item  Average dietary energy supply adequacy (percent) (3-year average)  \
# 0                                                 108.0
# 1                                                 108.0
# 2                                                 107.0
# 3                                                 106.0
# 4                                                 106.0
# ...                                                 ...
# 1219                                               94.0
# 1220                                               92.0
# 1221                                               91.0
# 1222                                               91.0
# 1223                                               91.0
#
# Item  Average fat supply (g/cap/day) (3-year average)  \
# 0                                                39.7
# 1                                                40.7
# 2                                                40.8
# 3                                                40.4
# 4                                                 NaN
# ...                                               ...
# 1219                                             66.9
# 1220                                             63.6
# 1221                                             63.3
# 1222                                              NaN
# 1223                                              NaN
#
# Item  Average protein supply (g/cap/day) (3-year average)  \
# 0                                                  58.3
# 1                                                  58.0
# 2                                                  57.3
# 3                                                  56.3
# 4                                                   NaN
# ...                                                 ...
# 1219                                               57.7
# 1220                                               55.6
# 1221                                               54.7
# 1222                                                NaN
# 1223                                                NaN
#
# Item  Average supply of protein of animal origin (g/cap/day) (3-year average)  \
# 0                                                  11.3
# 1                                                  10.7
# 2                                                  10.3
# 3                                                  10.0
# 4                                                   NaN
# ...                                                 ...
# 1219                                               25.3
# 1220                                               25.0
# 1221                                               24.7
# 1222                                                NaN
# 1223                                                NaN
#
# Item  Cereal import dependency ratio (percent) (3-year average)  \
# 0                                                  34.2
# 1                                                  41.3
# 2                                                  40.9
# 3                                                  38.1
# 4                                                   NaN
# ...                                                 ...
# 1219                                               35.3
# 1220                                               56.9
# 1221                                               60.3
# 1222                                                NaN
# 1223                                                NaN
#
# Item  Coefficient of variation of habitual caloric consumption distribution (real number)  \
# 0                                                  0.32
# 1                                                  0.32
# 2                                                  0.33
# 3                                                  0.39
# 4                                                  0.39
# ...                                                 ...
# 1219                                               0.32
# 1220                                               0.31
# 1221                                               0.31
# 1222                                               0.31
# 1223                                               0.29
#
# Item  Gross domestic product per capita, PPP, (constant 2017 international $)  \
# 0                                                2096.1
# 1                                                2060.7
# 2                                                2079.9
# 3                                                1968.3
# 4                                                1516.3
# ...                                                 ...
# 1219                                             2399.6
# 1220                                             2203.4
# 1221                                             1990.3
# 1222                                             2115.1
# 1223                                                NaN
#
# Item  Incidence of caloric losses at retail distribution level (percent)  \
# 0                                                  3.82
# 1                                                  3.82
# 2                                                  3.82
# 3                                                  3.82
# 4                                                  3.82
# ...                                                 ...
# 1219                                               2.13
# 1220                                               2.13
# 1221                                               2.13
# 1222                                               2.13
# 1223                                               2.13
#
# Item  Minimum dietary energy requirement  (kcal/cap/day)  \
# 0                                                1656.0
# 1                                                1659.0
# 2                                                1661.0
# 3                                                1665.0
# 4                                                1667.0
# ...                                                 ...
# 1219                                             1739.0
# 1220                                             1743.0
# 1221                                             1747.0
# 1222                                             1750.0
# 1223                                             1755.0
#
# Item  Per capita food production variability (constant 2014-2016 thousand int$ per capita)  \
# 0                                                   6.7
# 1                                                   5.6
# 2                                                   8.5
# 3                                                   8.6
# 4                                                   NaN
# ...                                                 ...
# 1219                                               19.7
# 1220                                                5.6
# 1221                                                5.6
# 1222                                                NaN
# 1223                                                NaN
#
# Item  Per capita food supply variability (kcal/cap/day)  \
# 0                                                  26.0
# 1                                                  27.0
# 2                                                  31.0
# 3                                                  32.0
# 4                                                  31.0
# ...                                                 ...
# 1219                                               53.0
# 1220                                               22.0
# 1221                                               20.0
# 1222                                               21.0
# 1223                                                NaN
#
# Item  Percentage of population using at least basic drinking water services (percent)  \
# 0                                                  66.8
# 1                                                  69.6
# 2                                                  72.4
# 3                                                  75.1
# 4                                                   NaN
# ...                                                 ...
# 1219                                               63.5
# 1220                                               63.1
# 1221                                               62.7
# 1222                                                NaN
# 1223                                                NaN
#
# Item  Percentage of population using at least basic sanitation services (percent)  \
# 0                                                  45.8
# 1                                                  47.4
# 2                                                  49.0
# 3                                                  50.5
# 4                                                   NaN
# ...                                                 ...
# 1219                                               36.4
# 1220                                               35.8
# 1221                                               35.2
# 1222                                                NaN
# 1223                                                NaN
#
# Item  Percentage of population using safely managed drinking water services (percent)  \
# 0                                                  25.1
# 1                                                  25.9
# 2                                                  26.8
# 3                                                  27.6
# 4                                                   NaN
# ...                                                 ...
# 1219                                               29.8
# 1220                                               29.7
# 1221                                               29.5
# 1222                                                NaN
# 1223                                                NaN
#
# Item  Percentage of population using safely managed sanitation services (percent)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1219                                               26.3
# 1220                                               26.0
# 1221                                               25.7
# 1222                                                NaN
# 1223                                                NaN
#
# Item  Rail lines density (total route in km per 100 square km of land area)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1219                                                0.8
# 1220                                                0.8
# 1221                                                0.8
# 1222                                                NaN
# 1223                                                NaN
#
# Item  Share of dietary energy supply derived from cereals, roots and tubers (percent) (3-year average)  \
# 0                                                  72.0
# 1                                                  72.0
# 2                                                  71.0
# 3                                                  71.0
# 4                                                   NaN
# ...                                                 ...
# 1219                                               53.0
# 1220                                               53.0
# 1221                                               53.0
# 1222                                                NaN
# 1223                                                NaN
#
# Item  Value of food imports in total merchandise exports (percent) (3-year average)
# 0                                                 388.0
# 1                                                 378.0
# 2                                                 311.0
# 3                                                 284.0
# 4                                                 238.0
# ...                                                 ...
# 1219                                               20.0
# 1220                                               13.0
# 1221                                               14.0
# 1222                                               15.0
# 1223                                                NaN
#
# [1224 rows x 20 columns]

# %%
df_pivot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1224 entries, 0 to 1223
# Data columns (total 20 columns):
#  #   Column                                                                                            Non-Null Count  Dtype
# ---  ------                                                                                            --------------  -----
#  0   Area                                                                                              1224 non-null   string
#  1   Year                                                                                              1224 non-null   int64
#  2   Average dietary energy supply adequacy (percent) (3-year average)                                 1048 non-null   float64
#  3   Average fat supply (g/cap/day) (3-year average)                                                   720 non-null    float64
#  4   Average protein supply (g/cap/day) (3-year average)                                               732 non-null    float64
#  5   Average supply of protein of animal origin (g/cap/day) (3-year average)                           732 non-null    float64
#  6   Cereal import dependency ratio (percent) (3-year average)                                         676 non-null    float64
#  7   Coefficient of variation of habitual caloric consumption distribution (real number)               1152 non-null   float64
#  8   Gross domestic product per capita, PPP, (constant 2017 international $)                           937 non-null    float64
#  9   Incidence of caloric losses at retail distribution level (percent)                                1218 non-null   float64
#  10  Minimum dietary energy requirement  (kcal/cap/day)                                                1164 non-null   float64
#  11  Per capita food production variability (constant 2014-2016 thousand int$ per capita)              796 non-null    float64
#  12  Per capita food supply variability (kcal/cap/day)                                                 870 non-null    float64
#  13  Percentage of population using at least basic drinking water services (percent)                   771 non-null    float64
#  14  Percentage of population using at least basic sanitation services (percent)                       759 non-null    float64
#  15  Percentage of population using safely managed drinking water services (percent)                   481 non-null    float64
#  16  Percentage of population using safely managed sanitation services (percent)                       473 non-null    float64
#  17  Rail lines density (total route in km per 100 square km of land area)                             294 non-null    float64
#  18  Share of dietary energy supply derived from cereals, roots and tubers (percent) (3-year average)  720 non-null    float64
#  19  Value of food imports in total merchandise exports (percent) (3-year average)                     972 non-null    float64
# dtypes: float64(18), int64(1), string(1)
# memory usage: 191.4 KB

# %%
df_pivot.describe()
# Out:
# Item          Year  \
# count  1224.000000
# mean   2019.500000
# std       1.708523
# min    2017.000000
# 25%    2018.000000
# 50%    2019.500000
# 75%    2021.000000
# max    2022.000000
#
# Item   Average dietary energy supply adequacy (percent) (3-year average)  \
# count                                        1048.000000
# mean                                          122.037214
# std                                            15.733257
# min                                            35.000000
# 25%                                           111.000000
# 50%                                           123.000000
# 75%                                           133.250000
# max                                           160.000000
#
# Item   Average fat supply (g/cap/day) (3-year average)  \
# count                                       720.000000
# mean                                         89.815833
# std                                          36.079445
# min                                          15.200000
# 25%                                          60.250000
# 50%                                          86.750000
# 75%                                         117.325000
# max                                         181.700000
#
# Item   Average protein supply (g/cap/day) (3-year average)  \
# count                                         732.000000
# mean                                           80.750546
# std                                            21.197421
# min                                            21.200000
# 25%                                            64.700000
# 50%                                            81.700000
# 75%                                            96.700000
# max                                           144.300000
#
# Item   Average supply of protein of animal origin (g/cap/day) (3-year average)  \
# count                                         732.000000
# mean                                           36.680874
# std                                            20.429617
# min                                             2.000000
# 25%                                            19.000000
# 50%                                            35.300000
# 75%                                            51.300000
# max                                           104.700000
#
# Item   Cereal import dependency ratio (percent) (3-year average)  \
# count                                         676.000000
# mean                                           26.726331
# std                                            68.241281
# min                                          -343.300000
# 25%                                             5.400000
# 50%                                            36.900000
# 75%                                            73.525000
# max                                           100.000000
#
# Item   Coefficient of variation of habitual caloric consumption distribution (real number)  \
# count                                        1152.000000
# mean                                            0.254800
# std                                             0.058323
# min                                             0.110000
# 25%                                             0.210000
# 50%                                             0.250000
# 75%                                             0.290000
# max                                             0.390000
#
# Item   Gross domestic product per capita, PPP, (constant 2017 international $)  \
# count                                         937.000000
# mean                                        20927.263287
# std                                         21809.174545
# min                                           705.000000
# 25%                                          4922.600000
# 50%                                         13589.700000
# 75%                                         30210.200000
# max                                        128437.000000
#
# Item   Incidence of caloric losses at retail distribution level (percent)  \
# count                                        1218.000000
# mean                                            2.494869
# std                                             0.755072
# min                                             1.160000
# 25%                                             1.910000
# 50%                                             2.415000
# 75%                                             3.020000
# max                                             5.760000
#
# Item   Minimum dietary energy requirement  (kcal/cap/day)  \
# count                                        1164.000000
# mean                                         1831.640893
# std                                            85.852700
# min                                          1642.000000
# 25%                                          1762.000000
# 50%                                          1835.500000
# 75%                                          1908.250000
# max                                          2057.000000
#
# Item   Per capita food production variability (constant 2014-2016 thousand int$ per capita)  \
# count                                         796.000000
# mean                                           18.748241
# std                                            20.019577
# min                                             0.300000
# 25%                                             6.275000
# 50%                                            11.550000
# 75%                                            23.400000
# max                                           172.000000
#
# Item   Per capita food supply variability (kcal/cap/day)  \
# count                                         870.000000
# mean                                           34.974713
# std                                            26.287852
# min                                             5.000000
# 25%                                            20.000000
# 50%                                            28.000000
# 75%                                            42.000000
# max                                           249.000000
#
# Item   Percentage of population using at least basic drinking water services (percent)  \
# count                                         771.000000
# mean                                           88.176005
# std                                            15.574577
# min                                            37.200000
# 25%                                            82.000000
# 50%                                            96.500000
# 75%                                            99.000000
# max                                            99.000000
#
# Item   Percentage of population using at least basic sanitation services (percent)  \
# count                                         759.000000
# mean                                           76.632543
# std                                            27.910744
# min                                             8.100000
# 25%                                            54.750000
# 50%                                            90.700000
# 75%                                            98.700000
# max                                            99.000000
#
# Item   Percentage of population using safely managed drinking water services (percent)  \
# count                                         481.000000
# mean                                           71.834096
# std                                            29.859429
# min                                             5.600000
# 25%                                            47.500000
# 50%                                            85.400000
# 75%                                            98.300000
# max                                            99.000000
#
# Item   Percentage of population using safely managed sanitation services (percent)  \
# count                                         473.000000
# mean                                           58.306131
# std                                            29.842905
# min                                             6.100000
# 25%                                            30.300000
# 50%                                            60.900000
# 75%                                            85.000000
# max                                            99.000000
#
# Item   Rail lines density (total route in km per 100 square km of land area)  \
# count                                         294.000000
# mean                                            2.754082
# std                                             2.983910
# min                                             0.100000
# 25%                                             0.500000
# 50%                                             1.800000
# 75%                                             3.600000
# max                                            11.900000
#
# Item   Share of dietary energy supply derived from cereals, roots and tubers (percent) (3-year average)  \
# count                                         720.000000
# mean                                           46.743056
# std                                            13.767464
# min                                            23.000000
# 25%                                            35.000000
# 50%                                            46.000000
# 75%                                            56.000000
# max                                            80.000000
#
# Item   Value of food imports in total merchandise exports (percent) (3-year average)
# count                                         972.000000
# mean                                           58.371399
# std                                           258.150123
# min                                             3.000000
# 25%                                             8.000000
# 50%                                            15.000000
# 75%                                            40.000000
# max                                          5735.000000

# %% [markdown]
# #### Geração dos arquivos de saída

# %%
df_pivot.to_excel('../output/food_security_industry_pivot.xlsx')
df_pivot.to_parquet('../output/food_security_industry_pivot.parquet')

# %% [markdown]
# # 3 Data modeling

# %% [markdown]
# > Give a brief introduction about the model. If you feel it would help, explain the math behind it.

# %% [markdown]
# ## 3.1 Identifying key variables

# %% [markdown]
# > Guide the reader around the thought proccess about which variables were considered key to the model.

# %% [markdown]
# ## 3.2 Building the model

# %% [markdown]
# > Guide the reader throughout the implementation and the decision of using the chosen model.

# %% [markdown]
# ## 3.3 Extracting insights

# %% [markdown]
# > Be very thorough about which insights can be concluded from the data and how.

# %% [markdown]
# # 4 Conclusion

# %% [markdown]
# > Summarize the insights previously found.

# %% [markdown]
# ## 4.1 Discussion

# %% [markdown]
# > What makes those insights relevant and how do they relate to the initial business needs?

# %% [markdown]
# ## 4.2 Next steps

# %% [markdown]
# > If it makes sense, talk about the next logical steps that should follow the conclusion.
